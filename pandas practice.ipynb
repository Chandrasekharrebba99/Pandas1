# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def meane(list1):
    sumi = 0
    for i in list1:
        sumi +=i
    avg = sumi/len(list1)
    return avg
meane(df["Fare"])
# Out:
# 32.2042079685746

# %%
del df["Ticket"]
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked
# ...

# %%
for i in df:
    if(i == "PassengerId" ):
        del df["PassengerId"]
df.head(3)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S

# %%
df.tail()
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 887         1       1              Graham, Miss. Margaret Edith  female  19.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889         1       1                     Behr, Mr. Karl Howell    male  26.0
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch   Fare Cabin Embarked
# 886      0      0  13.00   NaN        S
# 887      0      0  30.00   B42        S
# 888      1      2  23.45   NaN        S
# 889      0      0  30.00  C148        C
# 890      0      0   7.75   NaN        Q

# %%
def findNaN(list1):
    mcount = 0
    fcount = 0
    for i in list1:
        if(i == "male"):
            mcount +=1
        if(i == "female"):
            fcount +=1
    return "mail count is",mcount, "Femail count is",fcount
findNaN(df["Sex"])
# Out:
# ('mail count is', 577, 'Femail count is', 314)

# %%
def ageabove18(list1):
    count = 0
    for i in list1:
        if i >18:
            count+=1
            #return df
    print(count)
print("Age above 18 is:")
ageabove18(df['Age'])
# Out:
# Age above 18 is:
# 575

# %%
df == "object"
a = df.dtypes[df.dtypes == "object"].index
a
df[a].describe()
# Out:
# C:\Users\chandu\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#                         Name   Sex        Cabin Embarked
# count                    891   891          204      889
# unique                   891     2          147        3
# top     O'Brien, Mr. Timothy  male  C23 C25 C27        S
# freq                       1   577            4      644

# %%
for i in df:
    print(i)
# Out:
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Fare
# Cabin
# Embarked

# %%
df[["Name","Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
sh = df["Name"].describe()

sh
# Out:
# count                      891
# unique                     891
# top       O'Brien, Mr. Timothy
# freq                         1
# Name: Name, dtype: object

# %%
for i in sh:
    print(i)
# Out:
# 891
# 891
# O'Brien, Mr. Timothy
# 1

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[["Name"]][3:5]
# Out:
#                                            Name
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                      Allen, Mr. William Henry

# %%
sorted(df["Name"])
# Out:
# ['Abbing, Mr. Anthony',
#  'Abbott, Mr. Rossmore Edward',
#  'Abbott, Mrs. Stanton (Rosa Hunt)',
#  'Abelson, Mr. Samuel',
#  'Abelson, Mrs. Samuel (Hannah Wizosky)',
#  'Adahl, Mr. Mauritz Nils Martin',
#  'Adams, Mr. John',
#  'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Aks, Mrs. Sam (Leah Rosen)',
#  'Albimona, Mr. Nassef Cassem',
#  'Alexander, Mr. William',
#  'Alhomaki, Mr. Ilmari Rudolf',
#  'Ali, Mr. Ahmed',
#  'Ali, Mr. William',
#  'Allen, Miss. Elisabeth Walton',
#  'Allen, Mr. William Henry',
#  'Allison, Master. Hudson Trevor',
#  'Allison, Miss. Helen Loraine',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#  'Allum, Mr. Owen George',
#  'Andersen-Jensen, Miss. Carla Christine Nielsine',
#  'Anderson, Mr. Harry',
#  'Andersson, Master. Sigvard Harald Elias',
#  'Andersson, Miss. Ebba Iris Alfrida',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Miss. Ingeborg Constanzia',
# ...

# %%
df[""]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
count = 0
uniq = []
for i in df["Embarked"]:
    if(i not in uniq):
        uniq.append(i)
print(uniq)
# Out:
# ['S', 'C', 'Q', nan]

# %%
df["Embarked"][0]
# Out:
# 'S'

# %%
# convert catogorical data to Numerical
for i in range(len(df["Embarked"])):
    if(df["Embarked"][i] == "S"):
        df["Embarked"][i] = 1
    if(df["Embarked"][i] == "C"):
        df["Embarked"][i] = 2
    if(df["Embarked"][i] == "Q"):
        df["Embarked"][i] = 3
df["Embarked"]
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 886    1
# 887    1
# 888    1
# 889    2
# 890    3
# Name: Embarked, Length: 891, dtype: object

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked
# ...

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
del df["Age"]

# %%
del df["Cabin"]

# %%
import seaborn as sns
sns.countplot(df["Pclass"])

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
df["Embarked"].mode()
# Out:
# 0    1
# dtype: object

# %%
df["Embarked"].fillna(1)
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 886    1
# 887    1
# 888    1
# 889    2
# 890    3
# Name: Embarked, Length: 891, dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
#printing uniq elements
dd = ["s","d","f","d","f","s","s"]
li = []
for i in dd:
    if(i not in li):
        li.append(i)
print(li)
# Out:
# ['s', 'd', 'f']

# %%
for i in range(len(dd)):
    if(dd[i] == "s"):
        dd[i] = 1
print(dd)
# Out:
# [1, 'd', 'f', 'd', 'f', 1, 1]
